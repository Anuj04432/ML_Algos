# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Dataset loading
df = pd.read_csv("C:\\Users\\Anuj Kumar\\Desktop\\Machine Learning\\datasets\\knn_dataset.csv")

# %%
print(df.head())
print(df.describe())
print(df.isnull().sum())
print(df.shape)
# Out:
#    Feature1  Feature2  Feature3  Feature4  Feature5  Feature6  Feature7  \
# 0  1.212576  1.265308 -1.326139  0.854049 -0.833210  1.922198  0.286800
# 1 -0.819989 -1.403370  2.073606  2.143061  0.311124 -0.493494 -1.152299
# 2 -0.385633 -0.044067  0.746623  0.296163  2.100648 -1.229976  1.903351
# 3 -1.803629  2.271456  0.549801  2.068164 -0.313878 -0.658292 -0.370855
# 4  2.691911 -2.209386 -2.364481  1.755742  2.118316 -1.310885  0.137369
#
#    Feature8  Target
# 0 -1.110004       1
# 1  0.290853       1
# 2  1.379839       1
# 3 -1.812039       0
# 4 -0.980987       0
#          Feature1    Feature2    Feature3    Feature4    Feature5    Feature6  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean    -0.272489    0.516419   -0.010832    0.444699    0.513525   -0.448032
# std      1.642793    1.523558    1.581349    1.435665    1.739064    1.342242
# min     -4.885228   -4.011454   -5.468988   -3.051914   -4.976910   -4.172795
# 25%     -1.453839   -0.563297   -1.109657   -0.561181   -0.591765   -1.365432
# 50%     -0.292420    0.521520    0.068535    0.418715    0.667046   -0.565533
# 75%      0.884062    1.568441    1.153484    1.437785    1.749191    0.521343
# max      4.275262    4.377880    4.351506    4.260327    4.876240    3.378124
#
#          Feature7    Feature8      Target
# count  500.000000  500.000000  500.000000
# mean     0.491160   -0.034157    0.486000
# std      1.545646    0.959520    0.500305
# min     -4.875552   -3.324756    0.000000
# 25%     -0.523433   -0.676710    0.000000
# 50%      0.610544   -0.067333    0.000000
# 75%      1.594637    0.646769    1.000000
# max      4.443385    3.061947    1.000000
# Feature1    0
# Feature2    0
# Feature3    0
# Feature4    0
# Feature5    0
# Feature6    0
# Feature7    0
# Feature8    0
# Target      0
# dtype: int64
# (500, 9)

# %% [markdown]
# ### Visualization

# %%
plt.figure(figsize=(12,8))
plt.hist(df)
plt.show()

# %%
plt.figure(figsize=(8,6))

sns.heatmap(df.corr(), annot=True , cmap="coolwarm")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df)
plt.xticks(rotation=45)
plt.show()

# %%
X = df.drop(columns="Target")
y = df.Target

# %%
# Scalling

from sklearn.preprocessing import StandardScaler

std = StandardScaler()

x_scaled = std.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train , y_test = train_test_split(x_scaled,y,test_size=0.2,random_state=42)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (400, 8)
# (100, 8)
# (400,)
# (100,)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5,algorithm="auto", weights="uniform")

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
pred = knn.predict(X_test)

# %%
print(pred[0])
print(y_test[0])
# Out:
# 0
# 1

# %%
# Metrices

from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

print("confusion matrix: \n",confusion_matrix(y_test,pred))
print("classification report: \n",classification_report(y_test,pred))
print("accuracy score: ",(accuracy_score(y_test,pred))*100)
# Out:
# confusion matrix:
#  [[49  3]
#  [ 8 40]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90        52
#            1       0.93      0.83      0.88        48
#
#     accuracy                           0.89       100
#    macro avg       0.89      0.89      0.89       100
# weighted avg       0.89      0.89      0.89       100
#
# accuracy score:  89.0
